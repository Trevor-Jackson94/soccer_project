# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder

# %%
# Load csv file
points_df = pd.read_csv("res/2017_2022_PL_Standings.csv", encoding = "latin-1")
points_df
# Out:
#                    Source.Name  Rk            Squad  MP   W   D   L   GF  GA  \
# 0   2017_2018_PL_Standings.csv   1  Manchester City  38  32   4   2  106  27
# 1   2017_2018_PL_Standings.csv   2   Manchester Utd  38  25   6   7   68  28
# 2   2017_2018_PL_Standings.csv   3        Tottenham  38  23   8   7   74  36
# 3   2017_2018_PL_Standings.csv   4        Liverpool  38  21  12   5   84  38
# 4   2017_2018_PL_Standings.csv   5          Chelsea  38  21   7  10   62  38
# ..                         ...  ..              ...  ..  ..  ..  ..  ...  ..
# 95  2021_2022_PL_Standings.csv  16          Everton  38  11   6  21   43  66
# 96  2021_2022_PL_Standings.csv  17     Leeds United  38   9  11  18   42  79
# 97  2021_2022_PL_Standings.csv  18          Burnley  38   7  14  17   34  53
# 98  2021_2022_PL_Standings.csv  19          Watford  38   6   5  27   34  77
# 99  2021_2022_PL_Standings.csv  20     Norwich City  38   5   7  26   23  84
#
#     GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance  \
# 0   79  100    2.63  86.4  22.8  63.6    1.67       54070
# 1   40   81    2.13  60.7  41.7  18.9    0.50       74976
# 2   38   77    2.03  67.3  35.0  32.3    0.85       67953
# 3   46   75    1.97  72.8  34.0  38.8    1.02       53049
# 4   24   70    1.84  57.9  35.3  22.7    0.60       41282
# ..  ..  ...     ...   ...   ...   ...     ...         ...
# 95 -23   39    1.03  42.8  54.5 -11.7   -0.31       38446
# 96 -37   38    1.00  47.2  70.1 -23.0   -0.60       36308
# 97 -19   35    0.92  39.0  56.7 -17.7   -0.47       19278
# 98 -43   23    0.61  38.8  66.6 -27.8   -0.73       20614
# 99 -61   22    0.58  33.3  77.0 -43.6   -1.15       26836
#
#          Top Team Scorer                    Goalkeeper  \
# 0     Sergio Agüero - 21                       Ederson
# 1     Romelu Lukaku - 16                  David de Gea
# 2        Harry Kane - 30                   Hugo Lloris
# 3     Mohamed Salah - 32  Loris Karius, Simon Mignolet
# 4       Eden Hazard - 12              Thibaut Courtois
# ..                   ...                           ...
# 95      Richarlison - 10               Jordan Pickford
# 96         Raphinha - 11                 Illan Meslier
# 97     Maxwel Cornet - 9                     Nick Pope
# 98  Emmanuel Dennis - 10                    Ben Foster
# 99      Teemu Pukki - 11                      Tim Krul
#
#                                    Notes
# 0   ? Champions League via league finish
# 1   ? Champions League via league finish
# 2   ? Champions League via league finish
# 3   ? Champions League via league finish
# 4          ? Europa League via cup win 1
# ..                                   ...
# 95                                   NaN
# 96                                   NaN
# 97                             Relegated
# 98                             Relegated
# 99                             Relegated
#
# [100 rows x 20 columns]

# %%
# Drop columns not needed
points_df = points_df.drop(columns=["Top Team Scorer", "Goalkeeper","Notes"])
points_df
# Out:
#                    Source.Name  Rk            Squad  MP   W   D   L   GF  GA  \
# 0   2017_2018_PL_Standings.csv   1  Manchester City  38  32   4   2  106  27
# 1   2017_2018_PL_Standings.csv   2   Manchester Utd  38  25   6   7   68  28
# 2   2017_2018_PL_Standings.csv   3        Tottenham  38  23   8   7   74  36
# 3   2017_2018_PL_Standings.csv   4        Liverpool  38  21  12   5   84  38
# 4   2017_2018_PL_Standings.csv   5          Chelsea  38  21   7  10   62  38
# ..                         ...  ..              ...  ..  ..  ..  ..  ...  ..
# 95  2021_2022_PL_Standings.csv  16          Everton  38  11   6  21   43  66
# 96  2021_2022_PL_Standings.csv  17     Leeds United  38   9  11  18   42  79
# 97  2021_2022_PL_Standings.csv  18          Burnley  38   7  14  17   34  53
# 98  2021_2022_PL_Standings.csv  19          Watford  38   6   5  27   34  77
# 99  2021_2022_PL_Standings.csv  20     Norwich City  38   5   7  26   23  84
#
#     GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance
# 0   79  100    2.63  86.4  22.8  63.6    1.67       54070
# 1   40   81    2.13  60.7  41.7  18.9    0.50       74976
# 2   38   77    2.03  67.3  35.0  32.3    0.85       67953
# 3   46   75    1.97  72.8  34.0  38.8    1.02       53049
# 4   24   70    1.84  57.9  35.3  22.7    0.60       41282
# ..  ..  ...     ...   ...   ...   ...     ...         ...
# 95 -23   39    1.03  42.8  54.5 -11.7   -0.31       38446
# 96 -37   38    1.00  47.2  70.1 -23.0   -0.60       36308
# 97 -19   35    0.92  39.0  56.7 -17.7   -0.47       19278
# 98 -43   23    0.61  38.8  66.6 -27.8   -0.73       20614
# 99 -61   22    0.58  33.3  77.0 -43.6   -1.15       26836
#
# [100 rows x 17 columns]

# %%
# Merge calendar year into DataFrame
points_df["Year"] = points_df["Source.Name"].str.split("_", n=2, expand=True)[0].map(str)+"_"+points_df["Source.Name"].str.split("_", n=2, expand=True)[1]
points_df
# Out:
#                    Source.Name  Rk            Squad  MP   W   D   L   GF  GA  \
# 0   2017_2018_PL_Standings.csv   1  Manchester City  38  32   4   2  106  27
# 1   2017_2018_PL_Standings.csv   2   Manchester Utd  38  25   6   7   68  28
# 2   2017_2018_PL_Standings.csv   3        Tottenham  38  23   8   7   74  36
# 3   2017_2018_PL_Standings.csv   4        Liverpool  38  21  12   5   84  38
# 4   2017_2018_PL_Standings.csv   5          Chelsea  38  21   7  10   62  38
# ..                         ...  ..              ...  ..  ..  ..  ..  ...  ..
# 95  2021_2022_PL_Standings.csv  16          Everton  38  11   6  21   43  66
# 96  2021_2022_PL_Standings.csv  17     Leeds United  38   9  11  18   42  79
# 97  2021_2022_PL_Standings.csv  18          Burnley  38   7  14  17   34  53
# 98  2021_2022_PL_Standings.csv  19          Watford  38   6   5  27   34  77
# 99  2021_2022_PL_Standings.csv  20     Norwich City  38   5   7  26   23  84
#
#     GD  Pts  Pts/MP    xG   xGA   xGD  xGD/90  Attendance       Year
# 0   79  100    2.63  86.4  22.8  63.6    1.67       54070  2017_2018
# 1   40   81    2.13  60.7  41.7  18.9    0.50       74976  2017_2018
# 2   38   77    2.03  67.3  35.0  32.3    0.85       67953  2017_2018
# 3   46   75    1.97  72.8  34.0  38.8    1.02       53049  2017_2018
# 4   24   70    1.84  57.9  35.3  22.7    0.60       41282  2017_2018
# ..  ..  ...     ...   ...   ...   ...     ...         ...        ...
# 95 -23   39    1.03  42.8  54.5 -11.7   -0.31       38446  2021_2022
# 96 -37   38    1.00  47.2  70.1 -23.0   -0.60       36308  2021_2022
# 97 -19   35    0.92  39.0  56.7 -17.7   -0.47       19278  2021_2022
# 98 -43   23    0.61  38.8  66.6 -27.8   -0.73       20614  2021_2022
# 99 -61   22    0.58  33.3  77.0 -43.6   -1.15       26836  2021_2022
#
# [100 rows x 18 columns]

# %%
# Convert columns to list
print(list(points_df))
# Out:
# ['Source.Name', 'Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP', 'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance', 'Year']

# %%
# Drop Source.Name and change Years index
points_df2 = points_df[['Year','Rk', 'Squad', 'MP', 'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Pts/MP', 'xG', 'xGA', 'xGD', 'xGD/90', 'Attendance']]
points_df2
# Out:
#          Year  Rk            Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP  \
# 0   2017_2018   1  Manchester City  38  32   4   2  106  27  79  100    2.63
# 1   2017_2018   2   Manchester Utd  38  25   6   7   68  28  40   81    2.13
# 2   2017_2018   3        Tottenham  38  23   8   7   74  36  38   77    2.03
# 3   2017_2018   4        Liverpool  38  21  12   5   84  38  46   75    1.97
# 4   2017_2018   5          Chelsea  38  21   7  10   62  38  24   70    1.84
# ..        ...  ..              ...  ..  ..  ..  ..  ...  ..  ..  ...     ...
# 95  2021_2022  16          Everton  38  11   6  21   43  66 -23   39    1.03
# 96  2021_2022  17     Leeds United  38   9  11  18   42  79 -37   38    1.00
# 97  2021_2022  18          Burnley  38   7  14  17   34  53 -19   35    0.92
# 98  2021_2022  19          Watford  38   6   5  27   34  77 -43   23    0.61
# 99  2021_2022  20     Norwich City  38   5   7  26   23  84 -61   22    0.58
#
#       xG   xGA   xGD  xGD/90  Attendance
# 0   86.4  22.8  63.6    1.67       54070
# 1   60.7  41.7  18.9    0.50       74976
# 2   67.3  35.0  32.3    0.85       67953
# 3   72.8  34.0  38.8    1.02       53049
# 4   57.9  35.3  22.7    0.60       41282
# ..   ...   ...   ...     ...         ...
# 95  42.8  54.5 -11.7   -0.31       38446
# 96  47.2  70.1 -23.0   -0.60       36308
# 97  39.0  56.7 -17.7   -0.47       19278
# 98  38.8  66.6 -27.8   -0.73       20614
# 99  33.3  77.0 -43.6   -1.15       26836
#
# [100 rows x 17 columns]

# %%
# Encode Labels
le = LabelEncoder()
points_df3 = points_df2.copy()
points_df3["Squad"] = le.fit_transform(points_df3["Squad"])
points_df3
# Out:
#          Year  Rk  Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP    xG  \
# 0   2017_2018   1     15  38  32   4   2  106  27  79  100    2.63  86.4
# 1   2017_2018   2     16  38  25   6   7   68  28  40   81    2.13  60.7
# 2   2017_2018   3     23  38  23   8   7   74  36  38   77    2.03  67.3
# 3   2017_2018   4     14  38  21  12   5   84  38  46   75    1.97  72.8
# 4   2017_2018   5      7  38  21   7  10   62  38  24   70    1.84  57.9
# ..        ...  ..    ...  ..  ..  ..  ..  ...  ..  ..  ...     ...   ...
# 95  2021_2022  16      9  38  11   6  21   43  66 -23   39    1.03  42.8
# 96  2021_2022  17     12  38   9  11  18   42  79 -37   38    1.00  47.2
# 97  2021_2022  18      5  38   7  14  17   34  53 -19   35    0.92  39.0
# 98  2021_2022  19     24  38   6   5  27   34  77 -43   23    0.61  38.8
# 99  2021_2022  20     18  38   5   7  26   23  84 -61   22    0.58  33.3
#
#      xGA   xGD  xGD/90  Attendance
# 0   22.8  63.6    1.67       54070
# 1   41.7  18.9    0.50       74976
# 2   35.0  32.3    0.85       67953
# 3   34.0  38.8    1.02       53049
# 4   35.3  22.7    0.60       41282
# ..   ...   ...     ...         ...
# 95  54.5 -11.7   -0.31       38446
# 96  70.1 -23.0   -0.60       36308
# 97  56.7 -17.7   -0.47       19278
# 98  66.6 -27.8   -0.73       20614
# 99  77.0 -43.6   -1.15       26836
#
# [100 rows x 17 columns]

# %%
# Visually inspect relationship between Points and Squad
plt.scatter(points_df3.Squad, points_df3.Pts)
plt.xticks(points_df3.Squad)
plt.xlabel("Squad")
plt.ylabel("Total Points")
plt.show()

# %%
# Format data to meet 
X = points_df3.Squad.values.reshape(-1, 1)

# Assign the target variable, or the Salary column
y = points_df3.Pts

# Create model
model = LinearRegression()

# Fit model
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Examine shape of x
X.shape
# Out:
# (100, 1)

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (100,)

# %%
plt.scatter(X, y)
plt.plot(X, y_pred, color='red')
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-0.03086191]
# 53.08354958294718
