# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
# Load csv file
loss_df = pd.read_csv("2017_2022_EPL.csv")
loss_df
# Out:
#          Year  Rk  Squad  MP   W   D   L   GF  GA  GD  Pts  Pts/MP    xG  \
# 0   2017_2018   1     15  38  32   4   2  106  27  79  100    2.63  86.4
# 1   2017_2018   2     16  38  25   6   7   68  28  40   81    2.13  60.7
# 2   2017_2018   3     23  38  23   8   7   74  36  38   77    2.03  67.3
# 3   2017_2018   4     14  38  21  12   5   84  38  46   75    1.97  72.8
# 4   2017_2018   5      7  38  21   7  10   62  38  24   70    1.84  57.9
# ..        ...  ..    ...  ..  ..  ..  ..  ...  ..  ..  ...     ...   ...
# 95  2021_2022  16      9  38  11   6  21   43  66 -23   39    1.03  42.8
# 96  2021_2022  17     12  38   9  11  18   42  79 -37   38    1.00  47.2
# 97  2021_2022  18      5  38   7  14  17   34  53 -19   35    0.92  39.0
# 98  2021_2022  19     24  38   6   5  27   34  77 -43   23    0.61  38.8
# 99  2021_2022  20     18  38   5   7  26   23  84 -61   22    0.58  33.3
#
#      xGA   xGD  xGD/90  Attendance
# 0   22.8  63.6    1.67       54070
# ...

# %%
# Visually inspect relationship between Points and Squad
plt.scatter(loss_df.Squad, loss_df.L)
plt.xticks(loss_df.Squad)
plt.xlabel("Squad")
plt.ylabel("Loss")
plt.show()

# %%
# Attribute and label
X = loss_df['Squad'].values.reshape(-1,1)
y = loss_df['L'].values.reshape(-1,1)

# %%
# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Instantiate it and fit the model
regressor = LinearRegression()  
regressor.fit(X_train, y_train) #training the algorithm
# Out:
# LinearRegression()

# %%
#To retrieve the intercept:
print(regressor.intercept_)

#For retrieving the slope:
print(regressor.coef_)
# Out:
# [14.13331209]
# [[0.01888118]]

# %%
# Make predictions 
y_pred = regressor.predict(X_test)

# %%
# Compare the actual output values
loss_df2 = pd.DataFrame({'Actual': y_test.flatten(), 'Predicted': y_pred.flatten()})
loss_df2
# Out:
#     Actual  Predicted
# 0       13  14.643104
# 1       14  14.624223
# 2        7  14.567579
# 3       19  14.624223
# 4       15  14.208837
# 5       19  14.152193
# 6       16  14.510936
# 7       18  14.284362
# 8       15  14.208837
# 9       21  14.303243
# 10      17  14.284362
# 11      18  14.189956
# 12      22  14.605342
# 13      19  14.586460
# 14      15  14.303243
# 15      16  14.586460
# 16       8  14.265480
# 17      10  14.133312
# 18      19  14.171074
# 19      15  14.378767

# %%
# Visualize as bar graph
loss_df2 = loss_df2.head(25)
loss_df2.plot(kind='bar',figsize=(20,15))
plt.grid(which='major', linestyle='-', linewidth='0.3', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()
